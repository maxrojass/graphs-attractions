# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import os
import glob
import matplotlib as mpl

# Just making the plots look better
mpl.style.use('ggplot')
mpl.rcParams['figure.figsize'] = (8,6)
mpl.rcParams['font.size'] = 12

# %%
import pandas as pd
df = pd.read_csv("/Users/maxrojas/Desktop/BI/3period/datasets/gamlastan.csv")
df
# Out:
#                                                    Text  \
# 0     Unwinding in the old streets and buildings was...
# 1     A very unique old town in the heard of Stockho...
# 2     We had a great time walking down the path, eve...
# 3     Narrow streets, boutique shops and hotels. Tru...
# 4     This is a beautiful place to walk around. Bril...
# ...                                                 ...
# 6918  Lots of interesting old buildings and quaint n...
# 6919  A nice historic old town, with lots of quirky ...
# 6920  We visited Gamla Stan, the old town whilst on ...
# 6921  We had a wonderful time in Stockholm with our ...
# 6922  Pulled into port. Weather will be 73 F. This i...
#
#                                                   Title  Rating  \
# 0                                  Unwinding in History      50
# 1                                 Old Town - Gamla Stan      50
# 2     Cute walk lined with local and chain shops and...      50
# 3                                    Historic, romantic      40
# 4                                            Gamla Stan      50
# ...                                                 ...     ...
# 6918                                             Lovely      50
# 6919          Historic Old Town....Of Stories and More!      50
# 6920                                Lovely architecture      40
# 6921                           Stockholm and SPB Tourns      50
# 6922                              SPB Tour in Stockholm      50
#
#      DateOfExperience DateOfReview      Username  \
# 0           July 2019        Apr 7     mc1012can
# 1        October 2019        Apr 6    Emmanuel H
# 2          March 2020     Mar 2020         Patty
# 3          April 2019     Mar 2020      Ashley B
# 4          March 2020     Mar 2020  geelongexpat
# ...               ...          ...           ...
# 6918   September 2015     Sep 2015     Martina R
# 6919      August 2015     Sep 2015    AbhishekGB
# 6920   September 2015     Sep 2015       Rojo447
# 6921      August 2015     Sep 2015     BungeeBug
# 6922      August 2015     Sep 2015     Marilyn L
#
#                              UserLocation UserContribution UserLikes
# 0                        Guangzhou, China               58         1
# 1                 New York City, New York               51         1
# 2     Washington DC, District of Columbia              292        12
# 3                 Bakersfield, California               81        17
# 4                       Chatan-cho, Japan            1,034       300
# ...                                   ...              ...       ...
# 6918                     Cheshire England               49        20
# 6919               Prague, Czech Republic               70        20
# 6920              Romford, United Kingdom            1,638       228
# 6921             Gastonia, North Carolina               15        12
# 6922                         Toledo, Ohio              219        21
#
# [6923 rows x 9 columns]

# %%
df_Location = df.groupby(["UserLocation"]).size().sort_values().reset_index(name='count')
df_Location
# Out:
#                        UserLocation  count
# 0           , Auckland, New Zealand      1
# 1             North, South Carolina      1
# 2                   North Yorkshire      1
# 3     North Walsham, United Kingdom      1
# 4                       North Wales      1
# ...                             ...    ...
# 2631           Melbourne, Australia     61
# 2632              Sydney, Australia     69
# 2633        New York City, New York     70
# 2634         London, United Kingdom    259
# 2635              Stockholm, Sweden    317
#
# [2636 rows x 2 columns]

# %%
df_Location = df_Location.drop(df_Location[df_Location['count'] < 24].index)
df_Location['UserLocation']
# Out:
# 2615              Vancouver, Canada
# 2616               New Delhi, India
# 2617                Dublin, Ireland
# 2618               Hong Kong, China
# 2619                 Athens, Greece
# 2620     Manchester, United Kingdom
# 2621              Helsinki, Finland
# 2622      San Francisco, California
# 2623    Dubai, United Arab Emirates
# 2624               Perth, Australia
# 2625              Chicago, Illinois
# 2626                Toronto, Canada
# 2627            Brisbane, Australia
# 2628        Los Angeles, California
# 2629                   Oslo, Norway
# 2630           Singapore, Singapore
# 2631           Melbourne, Australia
# 2632              Sydney, Australia
# 2633        New York City, New York
# 2634         London, United Kingdom
# 2635              Stockholm, Sweden
# Name: UserLocation, dtype: object

# %%
df_DOF = df.groupby(["DateOfExperience"]).size().reset_index(name='count')
df_DOF
# Out:
#    DateOfExperience  count
# 0        April 2015      9
# 1        April 2016    138
# 2        April 2017    111
# 3        April 2018     77
# 4        April 2019     55
# ..              ...    ...
# 61   September 2015    158
# 62   September 2016    215
# 63   September 2017    169
# 64   September 2018    143
# 65   September 2019     79
#
# [66 rows x 2 columns]

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

y_pos = np.arange(len(df_Location))


y = plt.bar(y_pos, df_Location['count'], align='center', alpha=0.5)
x = plt.xticks(y_pos, df_Location['UserLocation'],rotation=90)
plt.ylabel('')
plt.title('top 15 Number of Reviewers over Cities in Gamla Stan')
# Out:
# Text(0.5, 1.0, 'top 15 Number of Reviewers over Cities in Gamla Stan')

# %%
import pandas as pd
from datetime import datetime
import numpy as np

df_DOF['datetime'] = pd.to_datetime(df_DOF['DateOfExperience'])

# %%
import pandas as pd
from datetime import datetime
import numpy as np
date_rng = pd.date_range(start='5/1/2013', end='3/1/2020', freq='m')

# %%
df_DOF['DD'] = pd.Series(date_rng)

# %%
df_DOF2 = df_DOF.drop(['datetime','DateOfExperience'], axis = 1)

# %%
import matplotlib.pyplot as plt
import datetime
import numpy as np

x = np.array([datetime.datetime(2013, 9, 28, i, 0) for i in range(24)])
y = np.random.randint(100, size=x.shape)

plt.plot(df_DOF['DateOfExperience'],df_DOF['count'])
plt.title('Time Series Graph for Date of Experience of Reviewers')
plt.show()

# %%
df_DOF
# Out:
#    DateOfExperience  count   datetime         DD
# 0        April 2015      9 2015-04-01 2013-05-31
# 1        April 2016    138 2016-04-01 2013-06-30
# 2        April 2017    111 2017-04-01 2013-07-31
# 3        April 2018     77 2018-04-01 2013-08-31
# 4        April 2019     55 2019-04-01 2013-09-30
# ..              ...    ...        ...        ...
# 61   September 2015    158 2015-09-01 2018-06-30
# 62   September 2016    215 2016-09-01 2018-07-31
# 63   September 2017    169 2017-09-01 2018-08-31
# 64   September 2018    143 2018-09-01 2018-09-30
# 65   September 2019     79 2019-09-01 2018-10-31
#
# [66 rows x 4 columns]

# %%
import pandas as pd
import numpy as np

reviews = pd.read_csv("/Users/maxrojas/Desktop/BI/3period/datasets/gamlastan.csv")

reviews = reviews.assign(
    DateOfExperience = reviews.DateOfExperience.map(lambda v: v.split(" ")[0] if pd.notnull(v) else np.nan),
    UserLocation = reviews.UserLocation.map(lambda v: v.split(" ")[0] if pd.notnull(v) else np.nan),
    Username = reviews.Username.map(lambda v: v.split(" ")[0] if pd.notnull(v) else np.nan),
    UserContribution = reviews.UserContribution.map(lambda v: v.split(" ")[0] if pd.notnull(v) else np.nan),
    UserLikes = reviews.UserLikes.map(lambda v: v.split(" ")[0] if pd.notnull(v) else np.nan),
    DateOfReview = reviews.DateOfReview.map(lambda v: v.split(" ")[0] if pd.notnull(v) else np.nan)
)
reviews.head(3)
# Out:
#                                                 Text  \
# 0  Unwinding in the old streets and buildings was...
# 1  A very unique old town in the heard of Stockho...
# 2  We had a great time walking down the path, eve...
#
#                                                Title  Rating DateOfExperience  \
# 0                               Unwinding in History      50             July
# 1                              Old Town - Gamla Stan      50          October
# 2  Cute walk lined with local and chain shops and...      50            March
#
#   DateOfReview   Username UserLocation UserContribution UserLikes
# 0          Apr  mc1012can   Guangzhou,               58         1
# 1          Apr   Emmanuel          New               51         1
# 2          Mar      Patty   Washington              292        12

# %%
(reviews
     .DateOfExperience
     .value_counts()
        ).plot.bar(y_pos, color='darkseagreen').set_title("Number of visist per month of Gamla Stan (2013-2020)")
# Out:
# Text(0.5, 1.0, 'Number of visist per month of Gamla Stan (2013-2020)')

# %%
(reviews
     .DateOfReview
     .value_counts()
        ).plot.bar(y_pos, color='red').set_title("Number of Reviews per month of Gamla Stan (2013-2020)")
# Out:
# Text(0.5, 1.0, 'Number of Reviews per month of Gamla Stan (2013-2020)')

# %%
(reviews
     .Rating
     .value_counts()
     
        ).plot.bar(y_pos, color='darkseagreen').set_title("Number of reviews per Rating category of Gamla Stan (2013-2020)")
# Out:
# Text(0.5, 1.0, 'Number of reviews per Rating category of Gamla Stan (2013-2020)')

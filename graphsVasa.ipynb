# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import os
import glob
import matplotlib as mpl

# Just making the plots look better
mpl.style.use('ggplot')
mpl.rcParams['figure.figsize'] = (8,6)
mpl.rcParams['font.size'] = 12

# %%
import pandas as pd
df = pd.read_csv("/Users/maxrojas/Desktop/BI/3period/datasets/vasa.csv")
df
# Out:
#                                                    Text  \
# 0     If you are ever in Stockholm, these two museum...
# 1     Really interesting and so well organised with ...
# 2     We planned 2 hours for Vasa museum but it was ...
# 3     It was a very nice experience being there.The ...
# 4     Travelling with my 11 year old and wanted to d...
# ...                                                 ...
# 2475  This restored shipwreck is absolutely remarkab...
# 2476  This museum is dedicated to the Vasa ship only...
# 2477  The ship has to be seen to be believed. It’s m...
# 2478  We were in Stockholm as part of a Scandinavia ...
# 2479  This museum was amazing, and the story of the ...
#
#                               Title  Rating DateOfExperience DateOfReview  \
# 0     Vasa museum and Nordic museum      50       March 2020       Mar 22
# 1               Well worth a visit.      50       March 2020       Mar 18
# 2           Awesome swedish history      50    February 2020       Mar 18
# 3     Vasa Museum-Something Special      40       March 2020       Mar 14
# 4                  Very interesting      40       March 2020       Mar 14
# ...                             ...     ...              ...          ...
# 2475          Should not be missed.      50   September 2018     Sep 2018
# 2476             history kept alive      40      August 2018     Sep 2018
# 2477                      Fantastic      50   September 2018     Sep 2018
# 2478      Glad we didn't skip this!      50      August 2018     Sep 2018
# 2479                       So cool!      50   September 2018     Sep 2018
#
#               Username              UserLocation UserContribution UserLikes
# 0      Travelin' Woman                       NaN                5       NaN
# 1     GoldfinchSuffolk                   Suffolk               21        10
# 2            Teodora M           Brasov, Romania               15       NaN
# 3                Patsa                       NaN                7       NaN
# 4              Gavin F  Aberdeen, United Kingdom               91        10
# ...                ...                       ...              ...       ...
# 2475            alan f   Los Angeles, California               21         4
# 2476             STEVE       Lugano, Switzerland              321        47
# 2477           Penny S       Canberra, Australia               76        13
# 2478         misc22016            Tigard, Oregon               12         1
# 2479      miichelle139           McKinney, Texas               34         6
#
# [2480 rows x 9 columns]

# %%
df_Location = df.groupby(["UserLocation"]).size().sort_values().reset_index(name='count')
df_Location
# Out:
#                  UserLocation  count
# 0                          AU      1
# 1          Odivelas, Portugal      1
# 2          Old Bar, Australia      1
# 3      Old Bridge, New Jersey      1
# 4             Olney, Maryland      1
# ...                       ...    ...
# 1180  Los Angeles, California     22
# 1181     Melbourne, Australia     32
# 1182        Sydney, Australia     37
# 1183   London, United Kingdom     92
# 1184        Stockholm, Sweden    100
#
# [1185 rows x 2 columns]

# %%
df_Location = df_Location.drop(df_Location[df_Location['count'] < 9].index)
df_Location['UserLocation']
# Out:
# 1165                         Athens, Greece
# 1166                    Canberra, Australia
# 1167                    Seattle, Washington
# 1168    Washington DC, District of Columbia
# 1169                    Adelaide, Australia
# 1170                    Copenhagen, Denmark
# 1171                        Dublin, Ireland
# 1172                      Chicago, Illinois
# 1173                     Bucharest, Romania
# 1174                        Toronto, Canada
# 1175              San Francisco, California
# 1176                    Brisbane, Australia
# 1177                   Singapore, Singapore
# 1178                New York City, New York
# 1179                       Perth, Australia
# 1180                Los Angeles, California
# 1181                   Melbourne, Australia
# 1182                      Sydney, Australia
# 1183                 London, United Kingdom
# 1184                      Stockholm, Sweden
# Name: UserLocation, dtype: object

# %%
df_DOF = df.groupby(["DateOfExperience"]).size().reset_index(name='count')
df_DOF
# Out:
#    DateOfExperience  count
# 0        April 2018     10
# 1        April 2019     99
# 2       August 2018    122
# 3       August 2019    220
# 4     December 2017      6
# 5     December 2018     84
# 6     December 2019     56
# 7     February 2018      9
# 8     February 2019     79
# 9     February 2020     47
# 10     January 2018      7
# 11     January 2019     69
# 12     January 2020     38
# 13        July 2017      1
# 14        July 2018     36
# 15        July 2019    269
# 16        June 2018     38
# 17        June 2019    232
# 18       March 2018      6
# 19       March 2019     91
# 20       March 2020     15
# 21         May 2018     23
# 22         May 2019    171
# 23    November 2017      9
# 24    November 2018     88
# 25    November 2019     54
# 26     October 2017      4
# 27     October 2018    122
# 28     October 2019     99
# 29   September 2018    216
# 30   September 2019    160

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

y_pos = np.arange(len(df_Location))


y = plt.bar(y_pos, df_Location['count'], align='center', alpha=0.5)
x = plt.xticks(y_pos, df_Location['UserLocation'],rotation=90)
plt.ylabel('')
plt.title('top 15 Number of Reviewers over Cities in Djugarden')
# Out:
# Text(0.5, 1.0, 'top 15 Number of Reviewers over Cities in Djugarden')

# %%
import pandas as pd
from datetime import datetime
import numpy as np

df_DOF['datetime'] = pd.to_datetime(df_DOF['DateOfExperience'])

# %%
import pandas as pd
from datetime import datetime
import numpy as np
date_rng = pd.date_range(start='5/1/2013', end='3/1/2020', freq='m')

# %%
df_DOF['DD'] = pd.Series(date_rng)

# %%
df_DOF2 = df_DOF.drop(['datetime','DateOfExperience'], axis = 1)

# %%
import matplotlib.pyplot as plt
import datetime
import numpy as np

x = np.array([datetime.datetime(2013, 9, 28, i, 0) for i in range(24)])
y = np.random.randint(100, size=x.shape)

plt.plot(df_DOF['DateOfExperience'],df_DOF['count'])
plt.title('Time Series Graph for Date of Experience of Reviewers')
plt.show()

# %%
df_DOF
# Out:
#    DateOfExperience  count   datetime         DD
# 0        April 2018     10 2018-04-01 2013-05-31
# 1        April 2019     99 2019-04-01 2013-06-30
# 2       August 2018    122 2018-08-01 2013-07-31
# 3       August 2019    220 2019-08-01 2013-08-31
# 4     December 2017      6 2017-12-01 2013-09-30
# 5     December 2018     84 2018-12-01 2013-10-31
# 6     December 2019     56 2019-12-01 2013-11-30
# 7     February 2018      9 2018-02-01 2013-12-31
# 8     February 2019     79 2019-02-01 2014-01-31
# 9     February 2020     47 2020-02-01 2014-02-28
# 10     January 2018      7 2018-01-01 2014-03-31
# 11     January 2019     69 2019-01-01 2014-04-30
# 12     January 2020     38 2020-01-01 2014-05-31
# 13        July 2017      1 2017-07-01 2014-06-30
# 14        July 2018     36 2018-07-01 2014-07-31
# 15        July 2019    269 2019-07-01 2014-08-31
# 16        June 2018     38 2018-06-01 2014-09-30
# 17        June 2019    232 2019-06-01 2014-10-31
# 18       March 2018      6 2018-03-01 2014-11-30
# 19       March 2019     91 2019-03-01 2014-12-31
# 20       March 2020     15 2020-03-01 2015-01-31
# 21         May 2018     23 2018-05-01 2015-02-28
# 22         May 2019    171 2019-05-01 2015-03-31
# 23    November 2017      9 2017-11-01 2015-04-30
# 24    November 2018     88 2018-11-01 2015-05-31
# 25    November 2019     54 2019-11-01 2015-06-30
# 26     October 2017      4 2017-10-01 2015-07-31
# 27     October 2018    122 2018-10-01 2015-08-31
# 28     October 2019     99 2019-10-01 2015-09-30
# 29   September 2018    216 2018-09-01 2015-10-31
# 30   September 2019    160 2019-09-01 2015-11-30

# %%
import pandas as pd
import numpy as np

reviews = pd.read_csv("/Users/maxrojas/Desktop/BI/3period/datasets/vasa.csv")

reviews = reviews.assign(
    DateOfExperience = reviews.DateOfExperience.map(lambda v: v.split(" ")[0] if pd.notnull(v) else np.nan),
    UserLocation = reviews.UserLocation.map(lambda v: v.split(" ")[0] if pd.notnull(v) else np.nan),
    Username = reviews.Username.map(lambda v: v.split(" ")[0] if pd.notnull(v) else np.nan),
    UserContribution = reviews.UserContribution.map(lambda v: v.split(" ")[0] if pd.notnull(v) else np.nan),
    UserLikes = reviews.UserLikes.map(lambda v: v.split(" ")[0] if pd.notnull(v) else np.nan),
    DateOfReview = reviews.DateOfReview.map(lambda v: v.split(" ")[0] if pd.notnull(v) else np.nan)
)
reviews.head(3)
# Out:
#                                                 Text  \
# 0  If you are ever in Stockholm, these two museum...
# 1  Really interesting and so well organised with ...
# 2  We planned 2 hours for Vasa museum but it was ...
#
#                            Title  Rating DateOfExperience DateOfReview  \
# 0  Vasa museum and Nordic museum      50            March          Mar
# 1            Well worth a visit.      50            March          Mar
# 2        Awesome swedish history      50         February          Mar
#
#            Username UserLocation UserContribution UserLikes
# 0         Travelin'          NaN                5       NaN
# 1  GoldfinchSuffolk      Suffolk               21        10
# 2           Teodora      Brasov,               15       NaN

# %%
(reviews
     .DateOfExperience
     .value_counts()
        ).plot.bar(y_pos, color='darkseagreen').set_title("Number of visist per month to Vasa Museum (2013-2020)")
# Out:
# Text(0.5, 1.0, 'Number of visist per month to Vasa Museum (2013-2020)')

# %%
(reviews
     .DateOfReview
     .value_counts()
        ).plot.bar(y_pos, color='red').set_title("Number of Reviews per month to Vasa Museum (2013-2020)")
# Out:
# Text(0.5, 1.0, 'Number of Reviews per month to Vasa Museum (2013-2020)')

# %%
(reviews
     .Rating
     .value_counts()
     
        ).plot.bar(y_pos, color='darkseagreen').set_title("Number of reviews per Rating category of Vasa Museum (2013-2020)")
# Out:
# Text(0.5, 1.0, 'Number of reviews per Rating category of Vasa Museum (2013-2020)')
